# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.image as mpimg
from mpl_toolkits.axes_grid1 import ImageGrid
from PIL import Image, ImageChops
from PIL import Image, ImageOps
def trim(im):
    bg = Image.new(im.mode, im.size, im.getpixel((0,0)))
    diff = ImageChops.difference(im, bg)
    diff = ImageChops.add(diff, diff, 2.0, -100)
    bbox = diff.getbbox()
    if bbox:
        return im.crop(bbox)
    
img1 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/temperature/super3d_hdf5_chk_0018_Slice_z_temperature.png')
img2 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/density/super3d_hdf5_chk_0018_Slice_z_density.png')
img3 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/helium_den/super3d_hdf5_chk_0018_Slice_z_he4_density.png')
img4 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/titanium_dens/super3d_hdf5_chk_0018_Slice_z_ti44_density.png')

img5 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/temperature/super3d_hdf5_chk_0100_Slice_z_temperature.png')
img6 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/density/super3d_hdf5_chk_0100_Slice_z_density.png')
img7 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/helium_den/super3d_hdf5_chk_0100_Slice_z_he4_density.png')
img8 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/titanium_dens/super3d_hdf5_chk_0100_Slice_z_ti44_density.png')

img9 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/temperature/super3d_hdf5_chk_0141_Slice_z_temperature.png')
img10 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/density/super3d_hdf5_chk_0141_Slice_z_density.png')
img11 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/helium_den/super3d_hdf5_chk_0141_Slice_z_he4_density.png')
img12 = mpimg.imread('/scratch/06984/tg862835/PAPER_RUNS/17km/plots/titanium_dens/super3d_hdf5_chk_0141_Slice_z_ti44_density.png')


imglist = [img1,img5,img9, img2,img6,img10, img3,img7,img11, img4,img8, img12]

fig = plt.figure(figsize=(10, 12), dpi=300)
columns = 3
rows = 4

grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4, 3),  # creates 2x2 grid of axes
                 axes_pad=0.0,  # pad between axes in inch.
                 )

for ax, im in zip(grid, imglist):
    # Iterating over the grid returns the Axes.
    #im = ImageOps.expand(im, border=1, fill=(0,0,0))
    ax.imshow(im)
    ax.spines['bottom'].set_color('0.1')
    ax.axis('auto')
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
plt.subplots_adjust(0,0,1,1)

plt.savefig('TempDensHeTiTogether_12panel.png', bbox_inches='tight', pad_inches = 0)
plt.show()
